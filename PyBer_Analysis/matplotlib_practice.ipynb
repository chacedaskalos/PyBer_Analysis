# %%
# %matplotlib inline

# %%
#import dependencies
import matplotlib.pyplot as plt

# %%
#set the x-axis to a list of strings for each month
x_axis=["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#set the y-axis to a list of floats as the total fare in US dollars accumulated for each month
y_axis =[10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create the plot
plt.xlabel("Month")
plt.ylabel("Fare ($)")
plt.title("PyBer Fares")
plt.plot(x_axis, y_axis, 'o', color="magenta", label="Boston")
plt.legend()

# %%
fig, ax=plt.subplots()
ax.set_xlabel("Date")
ax.set_ylabel("Fares ($)")
ax.set_title("PyBer Fare by Month")
ax.grid()
ax.barh(y_axis, x_axis, color="green", label="Boston")
ax.legend()

# %%
plt.scatter(y_axis, x_axis, color="red", label="Chicago")
plt.legend()
plt.title("PyBer Fare by Month")
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.xlim(0,50)
plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis,y_axis, s=y_axis)

# %%
y_axis_larger=[]
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(y_axis, x_axis, s=[i*5 for i in y_axis], color="magenta", alpha=1, edgecolor="blue", linewidth=2, label="Boston")
plt.legend()
plt.title("PyBer Fare by Month")
plt.xlabel("Fares($)")
plt.ylabel("Date")
plt.gca().invert_yaxis()
plt.xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
plt.pie(y_axis, labels=x_axis)

# %%
plt.subplots(figsize=(8, 8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct="%.1f%%", colors=colors)
plt.show()

# %%
fig, ax =plt.subplots()
ax.pie(y_axis, labels=x_axis)
plt.show()
